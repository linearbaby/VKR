# %%
# !pip install faiss-cpu
# !pip install -U sentence-transformers
import numpy as np
import torch
import os
import json
from itertools import islice
import pandas as pd
import faiss
import time
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
from faiss.contrib.ondisk import merge_ondisk

# %% [markdown]
# ### Constants

# %%
# FAISS constants
d = 768  # vectors dimensionality
nlist = 100
m = 12                             # number of subquantizers
k = 10
nbits = 8   # each subvector encodes with nbits, bucketing
probe = 10

index_dir = "/content/"
path_to_vectors = "/content/vectors/"


device = "cpu"
if torch.cuda.is_available():
  device = "cuda:0"

# %% [markdown]
# ### Loading and generating vectors utils

# %%
def generate_vectors(path_to_vectors=path_to_vectors, partitions=10, number=1_000_000, size=768):
  os.makedirs(path_to_vectors, exist_ok=True)
  for i in range(partitions):
    data = np.random.rand(number // partitions, 768)
    f = os.path.join(path_to_vectors + f"block_{i}.npy")
    np.save(f, data)
  
  with open(path_to_vectors + "meta.txt", "w") as f:
    files = [f"block_{i}.npy" for i in range(partitions)]
    ids = [(number // partitions * idx, number // partitions * (idx + 1)) for idx in range(partitions)]
    f.write(json.dumps({"file_num": partitions, "number": number, "file_to_ids" : 
                        dict(zip(files, ids))}))


def read_vectors_iterator(path_to_vectors=path_to_vectors):
  meta = {}
  try:
    with open(path_to_vectors + "meta.txt", "r") as f:
      meta = json.load(f)
    meta["file_to_ids"] # throughs exception
  except:
    print("wrong file format or file is not present in dirictory")
    return

  for filename, ids in meta["file_to_ids"].items():
    f = os.path.join(path_to_vectors, filename)
    yield np.load(f), ids

# %% [markdown]
# ### Model and data loading for text task

# %%
def load_data():
  # load simple dataset 
  df=pd.read_csv("https://github.com/franciscadias/data/raw/master/abcnews-date-text.csv")
  data=df.headline_text.to_list()
  return data

def load_model():
  return SentenceTransformer('distilbert-base-nli-mean-tokens')

# %% [markdown]
# ### FAISS utility functions

# %%
def train_index(data, d=d, nlist=nlist, m=m, k=k, nbits=nbits, index_dir=index_dir):
  quantizer = faiss.IndexFlatL2(d)
  index = faiss.IndexIVFPQ(quantizer, d, nlist, m, nbits)
  index.train(data)
  faiss.write_index(index, index_dir + "trained.index")
  return index

def populate_index(data_iterator, index_dir=index_dir):
  partition = 0
  for partition, data in enumerate(data_iterator):
    data, indicies = data
    print(f"adding part of data {partition} to index")
    index = faiss.read_index(index_dir + "trained.index")
    index.add_with_ids(data, np.arange(indicies[0], indicies[1]))
    faiss.write_index(index, index_dir + f"block_{partition}.index")
  
  # construct the output index
  index = faiss.read_index(index_dir + "trained.index")
  block_fnames = [
      index_dir + f"block_{idx}.index"
      for idx in range(partition)
  ]
  merge_ondisk(index, block_fnames, index_dir + "merged_index.ivfdata")
  faiss.write_index(index, index_dir + "populated.index")

def execute_query(query, k=k, probe=probe, populated_index_path=index_dir + "populated.index"):
  index = faiss.read_index(index_dir + "populated.index")
  index.nprobe = probe
  return index.search(query, k)

# %% [markdown]
# ### Text task solution pipeline

# %%
def text_generating_index_pipeline(partitions=10, training_part=0.5, path_to_vectors=path_to_vectors, path_to_index=index_dir):
  data = load_data()
  model = load_model()
  model.to(device)
  os.makedirs(path_to_vectors, exist_ok=True)

  print("decoding texts")
  meta = ({"file_num": partitions, "number": len(data), "file_to_ids" : {}})
  for idx in tqdm(range(partitions)):
    i0, i1 = int(idx * len(data) / partitions), int((idx + 1) * len(data) / partitions)
    if idx == partitions - 1:
      i1 = len(data)
    encoded = model.encode(data[i0:i1])
    f = os.path.join(path_to_vectors + f"block_{idx}.npy")
    np.save(f, encoded)
    meta["file_to_ids"][f"block_{idx}.npy"] = (i0, i1)

  with open(path_to_vectors + "meta.txt", "w") as f:
    f.write(json.dumps(meta))
  
  training_data = np.array([]).reshape((0, 768))
  print("generating train data")
  for idx in tqdm(range(int(partitions * training_part))):
    new_part = np.load(path_to_vectors + f"block_{idx}.npy")
    training_data = np.concatenate((training_data, new_part))
  
  print("training index")
  train_index(training_data, index_dir=path_to_index)
  populate_index(read_vectors_iterator(path_to_vectors), index_dir=path_to_index)

# %% [markdown]
# ### Generating index

# %%
text_generating_index_pipeline(1000)
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# decoding texts
# 100%|██████████| 1000/1000 [07:18<00:00,  2.28it/s]
# generating train data
# 100%|██████████| 500/500 [05:03<00:00,  1.65it/s]
# training index
# adding part of data 0 to index
# adding part of data 1 to index
# adding part of data 2 to index
# adding part of data 3 to index
# adding part of data 4 to index
# adding part of data 5 to index
# adding part of data 6 to index
# adding part of data 7 to index
# adding part of data 8 to index
# adding part of data 9 to index
# adding part of data 10 to index
# adding part of data 11 to index
# adding part of data 12 to index
# adding part of data 13 to index
# adding part of data 14 to index
# adding part of data 15 to index
# adding part of data 16 to index
# adding part of data 17 to index
# adding part of data 18 to index
# adding part of data 19 to index
# adding part of data 20 to index
# adding part of data 21 to index
# adding part of data 22 to index
# adding part of data 23 to index
# adding part of data 24 to index
# adding part of data 25 to index
# adding part of data 26 to index
# adding part of data 27 to index
# adding part of data 28 to index
# adding part of data 29 to index
# adding part of data 30 to index
# adding part of data 31 to index
# adding part of data 32 to index
# adding part of data 33 to index
# adding part of data 34 to index
# adding part of data 35 to index
# adding part of data 36 to index
# adding part of data 37 to index
# adding part of data 38 to index
# adding part of data 39 to index
# adding part of data 40 to index
# adding part of data 41 to index
# adding part of data 42 to index
# adding part of data 43 to index
# adding part of data 44 to index
# adding part of data 45 to index
# adding part of data 46 to index
# adding part of data 47 to index
# adding part of data 48 to index
# adding part of data 49 to index
# adding part of data 50 to index
# adding part of data 51 to index
# adding part of data 52 to index
# adding part of data 53 to index
# adding part of data 54 to index
# adding part of data 55 to index
# adding part of data 56 to index
# adding part of data 57 to index
# adding part of data 58 to index
# adding part of data 59 to index
# adding part of data 60 to index
# adding part of data 61 to index
# adding part of data 62 to index
# adding part of data 63 to index
# adding part of data 64 to index
# adding part of data 65 to index
# adding part of data 66 to index
# adding part of data 67 to index
# adding part of data 68 to index
# adding part of data 69 to index
# adding part of data 70 to index
# adding part of data 71 to index
# adding part of data 72 to index
# adding part of data 73 to index
# adding part of data 74 to index
# adding part of data 75 to index
# adding part of data 76 to index
# adding part of data 77 to index
# adding part of data 78 to index
# adding part of data 79 to index
# adding part of data 80 to index
# adding part of data 81 to index
# adding part of data 82 to index
# adding part of data 83 to index
# adding part of data 84 to index
# adding part of data 85 to index
# adding part of data 86 to index
# adding part of data 87 to index
# adding part of data 88 to index
# adding part of data 89 to index
# adding part of data 90 to index
# adding part of data 91 to index
# adding part of data 92 to index
# adding part of data 93 to index
# adding part of data 94 to index
# adding part of data 95 to index
# adding part of data 96 to index
# adding part of data 97 to index
# adding part of data 98 to index
# adding part of data 99 to index
# adding part of data 100 to index
# adding part of data 101 to index
# adding part of data 102 to index
# adding part of data 103 to index
# adding part of data 104 to index
# adding part of data 105 to index
# adding part of data 106 to index
# adding part of data 107 to index
# adding part of data 108 to index
# adding part of data 109 to index
# adding part of data 110 to index
# adding part of data 111 to index
# adding part of data 112 to index
# adding part of data 113 to index
# adding part of data 114 to index
# adding part of data 115 to index
# adding part of data 116 to index
# adding part of data 117 to index
# adding part of data 118 to index
# adding part of data 119 to index
# adding part of data 120 to index
# adding part of data 121 to index
# adding part of data 122 to index
# adding part of data 123 to index
# adding part of data 124 to index
# adding part of data 125 to index
# adding part of data 126 to index
# adding part of data 127 to index
# adding part of data 128 to index
# adding part of data 129 to index
# adding part of data 130 to index
# adding part of data 131 to index
# adding part of data 132 to index
# adding part of data 133 to index
# adding part of data 134 to index
# adding part of data 135 to index
# adding part of data 136 to index
# adding part of data 137 to index
# adding part of data 138 to index
# adding part of data 139 to index
# adding part of data 140 to index
# adding part of data 141 to index
# adding part of data 142 to index
# adding part of data 143 to index
# adding part of data 144 to index
# adding part of data 145 to index
# adding part of data 146 to index
# adding part of data 147 to index
# adding part of data 148 to index
# adding part of data 149 to index
# adding part of data 150 to index
# adding part of data 151 to index
# adding part of data 152 to index
# adding part of data 153 to index
# adding part of data 154 to index
# adding part of data 155 to index
# adding part of data 156 to index
# adding part of data 157 to index
# adding part of data 158 to index
# adding part of data 159 to index
# adding part of data 160 to index
# adding part of data 161 to index
# adding part of data 162 to index
# adding part of data 163 to index
# adding part of data 164 to index
# adding part of data 165 to index
# adding part of data 166 to index
# adding part of data 167 to index
# adding part of data 168 to index
# adding part of data 169 to index
# adding part of data 170 to index
# adding part of data 171 to index
# adding part of data 172 to index
# adding part of data 173 to index
# adding part of data 174 to index
# adding part of data 175 to index
# adding part of data 176 to index
# adding part of data 177 to index
# adding part of data 178 to index
# adding part of data 179 to index
# adding part of data 180 to index
# adding part of data 181 to index
# adding part of data 182 to index
# adding part of data 183 to index
# adding part of data 184 to index
# adding part of data 185 to index
# adding part of data 186 to index
# adding part of data 187 to index
# adding part of data 188 to index
# adding part of data 189 to index
# adding part of data 190 to index
# adding part of data 191 to index
# adding part of data 192 to index
# adding part of data 193 to index
# adding part of data 194 to index
# adding part of data 195 to index
# adding part of data 196 to index
# adding part of data 197 to index
# adding part of data 198 to index
# adding part of data 199 to index
# adding part of data 200 to index
# adding part of data 201 to index
# adding part of data 202 to index
# adding part of data 203 to index
# adding part of data 204 to index
# adding part of data 205 to index
# adding part of data 206 to index
# adding part of data 207 to index
# adding part of data 208 to index
# adding part of data 209 to index
# adding part of data 210 to index
# adding part of data 211 to index
# adding part of data 212 to index
# adding part of data 213 to index
# adding part of data 214 to index
# adding part of data 215 to index
# adding part of data 216 to index
# adding part of data 217 to index
# adding part of data 218 to index
# adding part of data 219 to index
# adding part of data 220 to index
# adding part of data 221 to index
# adding part of data 222 to index
# adding part of data 223 to index
# adding part of data 224 to index
# adding part of data 225 to index
# adding part of data 226 to index
# adding part of data 227 to index
# adding part of data 228 to index
# adding part of data 229 to index
# adding part of data 230 to index
# adding part of data 231 to index
# adding part of data 232 to index
# adding part of data 233 to index
# adding part of data 234 to index
# adding part of data 235 to index
# adding part of data 236 to index
# adding part of data 237 to index
# adding part of data 238 to index
# adding part of data 239 to index
# adding part of data 240 to index
# adding part of data 241 to index
# adding part of data 242 to index
# adding part of data 243 to index
# adding part of data 244 to index
# adding part of data 245 to index
# adding part of data 246 to index
# adding part of data 247 to index
# adding part of data 248 to index
# adding part of data 249 to index
# adding part of data 250 to index
# adding part of data 251 to index
# adding part of data 252 to index
# adding part of data 253 to index
# adding part of data 254 to index
# adding part of data 255 to index
# adding part of data 256 to index
# adding part of data 257 to index
# adding part of data 258 to index
# adding part of data 259 to index
# adding part of data 260 to index
# adding part of data 261 to index
# adding part of data 262 to index
# adding part of data 263 to index
# adding part of data 264 to index
# adding part of data 265 to index
# adding part of data 266 to index
# adding part of data 267 to index
# adding part of data 268 to index
# adding part of data 269 to index
# adding part of data 270 to index
# adding part of data 271 to index
# adding part of data 272 to index
# adding part of data 273 to index
# adding part of data 274 to index
# adding part of data 275 to index
# adding part of data 276 to index
# adding part of data 277 to index
# adding part of data 278 to index
# adding part of data 279 to index
# adding part of data 280 to index
# adding part of data 281 to index
# adding part of data 282 to index
# adding part of data 283 to index
# adding part of data 284 to index
# adding part of data 285 to index
# adding part of data 286 to index
# adding part of data 287 to index
# adding part of data 288 to index
# adding part of data 289 to index
# adding part of data 290 to index
# adding part of data 291 to index
# adding part of data 292 to index
# adding part of data 293 to index
# adding part of data 294 to index
# adding part of data 295 to index
# adding part of data 296 to index
# adding part of data 297 to index
# adding part of data 298 to index
# adding part of data 299 to index
# adding part of data 300 to index
# adding part of data 301 to index
# adding part of data 302 to index
# adding part of data 303 to index
# adding part of data 304 to index
# adding part of data 305 to index
# adding part of data 306 to index
# adding part of data 307 to index
# adding part of data 308 to index
# adding part of data 309 to index
# adding part of data 310 to index
# adding part of data 311 to index
# adding part of data 312 to index
# adding part of data 313 to index
# adding part of data 314 to index
# adding part of data 315 to index
# adding part of data 316 to index
# adding part of data 317 to index
# adding part of data 318 to index
# adding part of data 319 to index
# adding part of data 320 to index
# adding part of data 321 to index
# adding part of data 322 to index
# adding part of data 323 to index
# adding part of data 324 to index
# adding part of data 325 to index
# adding part of data 326 to index
# adding part of data 327 to index
# adding part of data 328 to index
# adding part of data 329 to index
# adding part of data 330 to index
# adding part of data 331 to index
# adding part of data 332 to index
# adding part of data 333 to index
# adding part of data 334 to index
# adding part of data 335 to index
# adding part of data 336 to index
# adding part of data 337 to index
# adding part of data 338 to index
# adding part of data 339 to index
# adding part of data 340 to index
# adding part of data 341 to index
# adding part of data 342 to index
# adding part of data 343 to index
# adding part of data 344 to index
# adding part of data 345 to index
# adding part of data 346 to index
# adding part of data 347 to index
# adding part of data 348 to index
# adding part of data 349 to index
# adding part of data 350 to index
# adding part of data 351 to index
# adding part of data 352 to index
# adding part of data 353 to index
# adding part of data 354 to index
# adding part of data 355 to index
# adding part of data 356 to index
# adding part of data 357 to index
# adding part of data 358 to index
# adding part of data 359 to index
# adding part of data 360 to index
# adding part of data 361 to index
# adding part of data 362 to index
# adding part of data 363 to index
# adding part of data 364 to index
# adding part of data 365 to index
# adding part of data 366 to index
# adding part of data 367 to index
# adding part of data 368 to index
# adding part of data 369 to index
# adding part of data 370 to index
# adding part of data 371 to index
# adding part of data 372 to index
# adding part of data 373 to index
# adding part of data 374 to index
# adding part of data 375 to index
# adding part of data 376 to index
# adding part of data 377 to index
# adding part of data 378 to index
# adding part of data 379 to index
# adding part of data 380 to index
# adding part of data 381 to index
# adding part of data 382 to index
# adding part of data 383 to index
# adding part of data 384 to index
# adding part of data 385 to index
# adding part of data 386 to index
# adding part of data 387 to index
# adding part of data 388 to index
# adding part of data 389 to index
# adding part of data 390 to index
# adding part of data 391 to index
# adding part of data 392 to index
# adding part of data 393 to index
# adding part of data 394 to index
# adding part of data 395 to index
# adding part of data 396 to index
# adding part of data 397 to index
# adding part of data 398 to index
# adding part of data 399 to index
# adding part of data 400 to index
# adding part of data 401 to index
# adding part of data 402 to index
# adding part of data 403 to index
# adding part of data 404 to index
# adding part of data 405 to index
# adding part of data 406 to index
# adding part of data 407 to index
# adding part of data 408 to index
# adding part of data 409 to index
# adding part of data 410 to index
# adding part of data 411 to index
# adding part of data 412 to index
# adding part of data 413 to index
# adding part of data 414 to index
# adding part of data 415 to index
# adding part of data 416 to index
# adding part of data 417 to index
# adding part of data 418 to index
# adding part of data 419 to index
# adding part of data 420 to index
# adding part of data 421 to index
# adding part of data 422 to index
# adding part of data 423 to index
# adding part of data 424 to index
# adding part of data 425 to index
# adding part of data 426 to index
# adding part of data 427 to index
# adding part of data 428 to index
# adding part of data 429 to index
# adding part of data 430 to index
# adding part of data 431 to index
# adding part of data 432 to index
# adding part of data 433 to index
# adding part of data 434 to index
# adding part of data 435 to index
# adding part of data 436 to index
# adding part of data 437 to index
# adding part of data 438 to index
# adding part of data 439 to index
# adding part of data 440 to index
# adding part of data 441 to index
# adding part of data 442 to index
# adding part of data 443 to index
# adding part of data 444 to index
# adding part of data 445 to index
# adding part of data 446 to index
# adding part of data 447 to index
# adding part of data 448 to index
# adding part of data 449 to index
# adding part of data 450 to index
# adding part of data 451 to index
# adding part of data 452 to index
# adding part of data 453 to index
# adding part of data 454 to index
# adding part of data 455 to index
# adding part of data 456 to index
# adding part of data 457 to index
# adding part of data 458 to index
# adding part of data 459 to index
# adding part of data 460 to index
# adding part of data 461 to index
# adding part of data 462 to index
# adding part of data 463 to index
# adding part of data 464 to index
# adding part of data 465 to index
# adding part of data 466 to index
# adding part of data 467 to index
# adding part of data 468 to index
# adding part of data 469 to index
# adding part of data 470 to index
# adding part of data 471 to index
# adding part of data 472 to index
# adding part of data 473 to index
# adding part of data 474 to index
# adding part of data 475 to index
# adding part of data 476 to index
# adding part of data 477 to index
# adding part of data 478 to index
# adding part of data 479 to index
# adding part of data 480 to index
# adding part of data 481 to index
# adding part of data 482 to index
# adding part of data 483 to index
# adding part of data 484 to index
# adding part of data 485 to index
# adding part of data 486 to index
# adding part of data 487 to index
# adding part of data 488 to index
# adding part of data 489 to index
# adding part of data 490 to index
# adding part of data 491 to index
# adding part of data 492 to index
# adding part of data 493 to index
# adding part of data 494 to index
# adding part of data 495 to index
# adding part of data 496 to index
# adding part of data 497 to index
# adding part of data 498 to index
# adding part of data 499 to index
# adding part of data 500 to index
# adding part of data 501 to index
# adding part of data 502 to index
# adding part of data 503 to index
# adding part of data 504 to index
# adding part of data 505 to index
# adding part of data 506 to index
# adding part of data 507 to index
# adding part of data 508 to index
# adding part of data 509 to index
# adding part of data 510 to index
# adding part of data 511 to index
# adding part of data 512 to index
# adding part of data 513 to index
# adding part of data 514 to index
# adding part of data 515 to index
# adding part of data 516 to index
# adding part of data 517 to index
# adding part of data 518 to index
# adding part of data 519 to index
# adding part of data 520 to index
# adding part of data 521 to index
# adding part of data 522 to index
# adding part of data 523 to index
# adding part of data 524 to index
# adding part of data 525 to index
# adding part of data 526 to index
# adding part of data 527 to index
# adding part of data 528 to index
# adding part of data 529 to index
# adding part of data 530 to index
# adding part of data 531 to index
# adding part of data 532 to index
# adding part of data 533 to index
# adding part of data 534 to index
# adding part of data 535 to index
# adding part of data 536 to index
# adding part of data 537 to index
# adding part of data 538 to index
# adding part of data 539 to index
# adding part of data 540 to index
# adding part of data 541 to index
# adding part of data 542 to index
# adding part of data 543 to index
# adding part of data 544 to index
# adding part of data 545 to index
# adding part of data 546 to index
# adding part of data 547 to index
# adding part of data 548 to index
# adding part of data 549 to index
# adding part of data 550 to index
# adding part of data 551 to index
# adding part of data 552 to index
# adding part of data 553 to index
# adding part of data 554 to index
# adding part of data 555 to index
# adding part of data 556 to index
# adding part of data 557 to index
# adding part of data 558 to index
# adding part of data 559 to index
# adding part of data 560 to index
# adding part of data 561 to index
# adding part of data 562 to index
# adding part of data 563 to index
# adding part of data 564 to index
# adding part of data 565 to index
# adding part of data 566 to index
# adding part of data 567 to index
# adding part of data 568 to index
# adding part of data 569 to index
# adding part of data 570 to index
# adding part of data 571 to index
# adding part of data 572 to index
# adding part of data 573 to index
# adding part of data 574 to index
# adding part of data 575 to index
# adding part of data 576 to index
# adding part of data 577 to index
# adding part of data 578 to index
# adding part of data 579 to index
# adding part of data 580 to index
# adding part of data 581 to index
# adding part of data 582 to index
# adding part of data 583 to index
# adding part of data 584 to index
# adding part of data 585 to index
# adding part of data 586 to index
# adding part of data 587 to index
# adding part of data 588 to index
# adding part of data 589 to index
# adding part of data 590 to index
# adding part of data 591 to index
# adding part of data 592 to index
# adding part of data 593 to index
# adding part of data 594 to index
# adding part of data 595 to index
# adding part of data 596 to index
# adding part of data 597 to index
# adding part of data 598 to index
# adding part of data 599 to index
# adding part of data 600 to index
# adding part of data 601 to index
# adding part of data 602 to index
# adding part of data 603 to index
# adding part of data 604 to index
# adding part of data 605 to index
# adding part of data 606 to index
# adding part of data 607 to index
# adding part of data 608 to index
# adding part of data 609 to index
# adding part of data 610 to index
# adding part of data 611 to index
# adding part of data 612 to index
# adding part of data 613 to index
# adding part of data 614 to index
# adding part of data 615 to index
# adding part of data 616 to index
# adding part of data 617 to index
# adding part of data 618 to index
# adding part of data 619 to index
# adding part of data 620 to index
# adding part of data 621 to index
# adding part of data 622 to index
# adding part of data 623 to index
# adding part of data 624 to index
# adding part of data 625 to index
# adding part of data 626 to index
# adding part of data 627 to index
# adding part of data 628 to index
# adding part of data 629 to index
# adding part of data 630 to index
# adding part of data 631 to index
# adding part of data 632 to index
# adding part of data 633 to index
# adding part of data 634 to index
# adding part of data 635 to index
# adding part of data 636 to index
# adding part of data 637 to index
# adding part of data 638 to index
# adding part of data 639 to index
# adding part of data 640 to index
# adding part of data 641 to index
# adding part of data 642 to index
# adding part of data 643 to index
# adding part of data 644 to index
# adding part of data 645 to index
# adding part of data 646 to index
# adding part of data 647 to index
# adding part of data 648 to index
# adding part of data 649 to index
# adding part of data 650 to index
# adding part of data 651 to index
# adding part of data 652 to index
# adding part of data 653 to index
# adding part of data 654 to index
# adding part of data 655 to index
# adding part of data 656 to index
# adding part of data 657 to index
# adding part of data 658 to index
# adding part of data 659 to index
# adding part of data 660 to index
# adding part of data 661 to index
# adding part of data 662 to index
# adding part of data 663 to index
# adding part of data 664 to index
# adding part of data 665 to index
# adding part of data 666 to index
# adding part of data 667 to index
# adding part of data 668 to index
# adding part of data 669 to index
# adding part of data 670 to index
# adding part of data 671 to index
# adding part of data 672 to index
# adding part of data 673 to index
# adding part of data 674 to index
# adding part of data 675 to index
# adding part of data 676 to index
# adding part of data 677 to index
# adding part of data 678 to index
# adding part of data 679 to index
# adding part of data 680 to index
# adding part of data 681 to index
# adding part of data 682 to index
# adding part of data 683 to index
# adding part of data 684 to index
# adding part of data 685 to index
# adding part of data 686 to index
# adding part of data 687 to index
# adding part of data 688 to index
# adding part of data 689 to index
# adding part of data 690 to index
# adding part of data 691 to index
# adding part of data 692 to index
# adding part of data 693 to index
# adding part of data 694 to index
# adding part of data 695 to index
# adding part of data 696 to index
# adding part of data 697 to index
# adding part of data 698 to index
# adding part of data 699 to index
# adding part of data 700 to index
# adding part of data 701 to index
# adding part of data 702 to index
# adding part of data 703 to index
# adding part of data 704 to index
# adding part of data 705 to index
# adding part of data 706 to index
# adding part of data 707 to index
# adding part of data 708 to index
# adding part of data 709 to index
# adding part of data 710 to index
# adding part of data 711 to index
# adding part of data 712 to index
# adding part of data 713 to index
# adding part of data 714 to index
# adding part of data 715 to index
# adding part of data 716 to index
# adding part of data 717 to index
# adding part of data 718 to index
# adding part of data 719 to index
# adding part of data 720 to index
# adding part of data 721 to index
# adding part of data 722 to index
# adding part of data 723 to index
# adding part of data 724 to index
# adding part of data 725 to index
# adding part of data 726 to index
# adding part of data 727 to index
# adding part of data 728 to index
# adding part of data 729 to index
# adding part of data 730 to index
# adding part of data 731 to index
# adding part of data 732 to index
# adding part of data 733 to index
# adding part of data 734 to index
# adding part of data 735 to index
# adding part of data 736 to index
# adding part of data 737 to index
# adding part of data 738 to index
# adding part of data 739 to index
# adding part of data 740 to index
# adding part of data 741 to index
# adding part of data 742 to index
# adding part of data 743 to index
# adding part of data 744 to index
# adding part of data 745 to index
# adding part of data 746 to index
# adding part of data 747 to index
# adding part of data 748 to index
# adding part of data 749 to index
# adding part of data 750 to index
# adding part of data 751 to index
# adding part of data 752 to index
# adding part of data 753 to index
# adding part of data 754 to index
# adding part of data 755 to index
# adding part of data 756 to index
# adding part of data 757 to index
# adding part of data 758 to index
# adding part of data 759 to index
# adding part of data 760 to index
# adding part of data 761 to index
# adding part of data 762 to index
# adding part of data 763 to index
# adding part of data 764 to index
# adding part of data 765 to index
# adding part of data 766 to index
# adding part of data 767 to index
# adding part of data 768 to index
# adding part of data 769 to index
# adding part of data 770 to index
# adding part of data 771 to index
# adding part of data 772 to index
# adding part of data 773 to index
# adding part of data 774 to index
# adding part of data 775 to index
# adding part of data 776 to index
# adding part of data 777 to index
# adding part of data 778 to index
# adding part of data 779 to index
# adding part of data 780 to index
# adding part of data 781 to index
# adding part of data 782 to index
# adding part of data 783 to index
# adding part of data 784 to index
# adding part of data 785 to index
# adding part of data 786 to index
# adding part of data 787 to index
# adding part of data 788 to index
# adding part of data 789 to index
# adding part of data 790 to index
# adding part of data 791 to index
# adding part of data 792 to index
# adding part of data 793 to index
# adding part of data 794 to index
# adding part of data 795 to index
# adding part of data 796 to index
# adding part of data 797 to index
# adding part of data 798 to index
# adding part of data 799 to index
# adding part of data 800 to index
# adding part of data 801 to index
# adding part of data 802 to index
# adding part of data 803 to index
# adding part of data 804 to index
# adding part of data 805 to index
# adding part of data 806 to index
# adding part of data 807 to index
# adding part of data 808 to index
# adding part of data 809 to index
# adding part of data 810 to index
# adding part of data 811 to index
# adding part of data 812 to index
# adding part of data 813 to index
# adding part of data 814 to index
# adding part of data 815 to index
# adding part of data 816 to index
# adding part of data 817 to index
# adding part of data 818 to index
# adding part of data 819 to index
# adding part of data 820 to index
# adding part of data 821 to index
# adding part of data 822 to index
# adding part of data 823 to index
# adding part of data 824 to index
# adding part of data 825 to index
# adding part of data 826 to index
# adding part of data 827 to index
# adding part of data 828 to index
# adding part of data 829 to index
# adding part of data 830 to index
# adding part of data 831 to index
# adding part of data 832 to index
# adding part of data 833 to index
# adding part of data 834 to index
# adding part of data 835 to index
# adding part of data 836 to index
# adding part of data 837 to index
# adding part of data 838 to index
# adding part of data 839 to index
# adding part of data 840 to index
# adding part of data 841 to index
# adding part of data 842 to index
# adding part of data 843 to index
# adding part of data 844 to index
# adding part of data 845 to index
# adding part of data 846 to index
# adding part of data 847 to index
# adding part of data 848 to index
# adding part of data 849 to index
# adding part of data 850 to index
# adding part of data 851 to index
# adding part of data 852 to index
# adding part of data 853 to index
# adding part of data 854 to index
# adding part of data 855 to index
# adding part of data 856 to index
# adding part of data 857 to index
# adding part of data 858 to index
# adding part of data 859 to index
# adding part of data 860 to index
# adding part of data 861 to index
# adding part of data 862 to index
# adding part of data 863 to index
# adding part of data 864 to index
# adding part of data 865 to index
# adding part of data 866 to index
# adding part of data 867 to index
# adding part of data 868 to index
# adding part of data 869 to index
# adding part of data 870 to index
# adding part of data 871 to index
# adding part of data 872 to index
# adding part of data 873 to index
# adding part of data 874 to index
# adding part of data 875 to index
# adding part of data 876 to index
# adding part of data 877 to index
# adding part of data 878 to index
# adding part of data 879 to index
# adding part of data 880 to index
# adding part of data 881 to index
# adding part of data 882 to index
# adding part of data 883 to index
# adding part of data 884 to index
# adding part of data 885 to index
# adding part of data 886 to index
# adding part of data 887 to index
# adding part of data 888 to index
# adding part of data 889 to index
# adding part of data 890 to index
# adding part of data 891 to index
# adding part of data 892 to index
# adding part of data 893 to index
# adding part of data 894 to index
# adding part of data 895 to index
# adding part of data 896 to index
# adding part of data 897 to index
# adding part of data 898 to index
# adding part of data 899 to index
# adding part of data 900 to index
# adding part of data 901 to index
# adding part of data 902 to index
# adding part of data 903 to index
# adding part of data 904 to index
# adding part of data 905 to index
# adding part of data 906 to index
# adding part of data 907 to index
# adding part of data 908 to index
# adding part of data 909 to index
# adding part of data 910 to index
# adding part of data 911 to index
# adding part of data 912 to index
# adding part of data 913 to index
# adding part of data 914 to index
# adding part of data 915 to index
# adding part of data 916 to index
# adding part of data 917 to index
# adding part of data 918 to index
# adding part of data 919 to index
# adding part of data 920 to index
# adding part of data 921 to index
# adding part of data 922 to index
# adding part of data 923 to index
# adding part of data 924 to index
# adding part of data 925 to index
# adding part of data 926 to index
# adding part of data 927 to index
# adding part of data 928 to index
# adding part of data 929 to index
# adding part of data 930 to index
# adding part of data 931 to index
# adding part of data 932 to index
# adding part of data 933 to index
# adding part of data 934 to index
# adding part of data 935 to index
# adding part of data 936 to index
# adding part of data 937 to index
# adding part of data 938 to index
# adding part of data 939 to index
# adding part of data 940 to index
# adding part of data 941 to index
# adding part of data 942 to index
# adding part of data 943 to index
# adding part of data 944 to index
# adding part of data 945 to index
# adding part of data 946 to index
# adding part of data 947 to index
# adding part of data 948 to index
# adding part of data 949 to index
# adding part of data 950 to index
# adding part of data 951 to index
# adding part of data 952 to index
# adding part of data 953 to index
# adding part of data 954 to index
# adding part of data 955 to index
# adding part of data 956 to index
# adding part of data 957 to index
# adding part of data 958 to index
# adding part of data 959 to index
# adding part of data 960 to index
# adding part of data 961 to index
# adding part of data 962 to index
# adding part of data 963 to index
# adding part of data 964 to index
# adding part of data 965 to index
# adding part of data 966 to index
# adding part of data 967 to index
# adding part of data 968 to index
# adding part of data 969 to index
# adding part of data 970 to index
# adding part of data 971 to index
# adding part of data 972 to index
# adding part of data 973 to index
# adding part of data 974 to index
# adding part of data 975 to index
# adding part of data 976 to index
# adding part of data 977 to index
# adding part of data 978 to index
# adding part of data 979 to index
# adding part of data 980 to index
# adding part of data 981 to index
# adding part of data 982 to index
# adding part of data 983 to index
# adding part of data 984 to index
# adding part of data 985 to index
# adding part of data 986 to index
# adding part of data 987 to index
# adding part of data 988 to index
# adding part of data 989 to index
# adding part of data 990 to index
# adding part of data 991 to index
# adding part of data 992 to index
# adding part of data 993 to index
# adding part of data 994 to index
# adding part of data 995 to index
# adding part of data 996 to index
# adding part of data 997 to index
# adding part of data 998 to index
# adding part of data 999 to index

# %% [markdown]
# ### Querying index

# %%
model = load_model()
model.to(device)
data = load_data()

# %%
execute_query(model.encode(data[:5]))
# Out:
# (array([[ 71.38407 ,  84.14787 ,  86.641426,  86.70545 ,  86.98414 ,
#           88.393394,  89.011826,  89.27888 ,  90.28634 ,  90.89114 ],
#         [ 89.8884  , 108.68803 , 109.99781 , 110.69162 , 111.576546,
#          112.152794, 113.09178 , 113.09522 , 113.553474, 113.887436],
#         [ 66.44713 ,  81.6371  ,  82.32962 ,  83.49385 ,  85.31445 ,
#           85.33592 ,  85.78581 ,  85.80759 ,  86.21858 ,  87.25972 ],
#         [ 90.70556 ,  97.824234, 100.00536 , 101.104004, 101.54645 ,
#          102.37016 , 104.18228 , 105.69875 , 106.291   , 106.41821 ],
#         [ 68.743195,  85.63048 ,  86.62741 ,  87.617516,  88.79246 ,
#           89.03182 ,  90.634476,  91.612206,  91.84524 ,  91.846275]],
#        dtype=float32),
#  array([[      0,  116826,   75117,   33519, 1063832,  181021,   21498,
#           849971,  665155, 1062953],
#         [      1,  262540,  901689,  621413,   43449,  273522,  105431,
#             4572,  667934,  142663],
#         [      2,  350162,  390736,    2029,  261048,   11678,   36894,
#           418282,  996517,  975302],
#         [      3,  408801,   28128,    4805,  512029,   33887,  289143,
#           169987,  387149,  999341],
#         [      4,  570018,  806724,  957817,   69063,  553809,  439979,
#           932188,  649009,  956151]]))

# %% [markdown]
# Можно заметить, в полученных результатах, текстовый эквивалент которых приведен ниже, что движок для поиска ближайших соседей основанный на индексе FAISS действительно работает.

# %%
for data_index in [0, 116826, 75117, 33519, 1063832, 181021, 21498,849971, 665155, 1062953]:
  print(data[data_index])
# Out:
# aba decides against community broadcasting licence
# council bans bondi butts
# commonwealth requests media ban from high court
# court overturns muslim centre ban
# judge blocks trumps travel ban
# lantana to be banned from wa
# aba suspends wagin radio licence
# judge throws out attempt to limit eastman inquiry
# council bans csg projects
# brenton kelly dickson appeal denied

# %%
for data_index in [1, 262540, 901689, 621413, 43449, 273522, 105431, 4572, 667934, 142663]:
  print(data[data_index])
# Out:
# act fire witnesses must be aware of defamation
# accused abuser threatens defamation against
# cfmeu officials respond to allegations of intimidation
# bashing victim pleads for witnesses
# carr stands by blackmail claims
# prouds accused of misleading advertising
# ethicist under fire for human rights views
# warne and lee blackmail witness statements
# albanese accused of plagiarising speech
# lawyers criticise surveillance of habib

# %%
for data_index in [3, 408801, 28128, 4805, 512029, 33887, 289143, 169987, 387149, 999341]:
  print(data[data_index])
# Out:
# air nz staff in aust strike for pay rise
# tafe lecturers call for pay rise
# childcare workers apply to airc for pay rise
# workers union set to campaign for pay rise
# maritime workers strike for big pay rise
# salt works staff seek pay rise
# bridgestone workers to strike to get pay rise
# councillors push for pay rise
# union seeks pay rise for academic staff
# call for mackay council workers to get interim pay rise
